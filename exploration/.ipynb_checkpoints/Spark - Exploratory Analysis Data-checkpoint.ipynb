# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# %% [markdown]
# ## Load the data and sample a part to have as 'train' data

# %%
airports_full = pd.read_csv("venv/1990.csv.bz2", compression='bz2')
airports_full = airports_full.drop(["ArrTime", "ActualElapsedTime", "AirTime", "TaxiIn", "Diverted", "CarrierDelay",
                         "WeatherDelay", "NASDelay", "SecurityDelay", "LateAircraftDelay"], axis=1)
airports = airports_full.sample(frac=0.9, replace=False, random_state=42)

# %%
airports.count()
# Out:
# Year                4743804
# Month               4743804
# DayofMonth          4743804
# DayOfWeek           4743804
# DepTime             4696662
# CRSDepTime          4743804
# CRSArrTime          4743804
# UniqueCarrier       4743804
# FlightNum           4743804
# TailNum                   0
# CRSElapsedTime      4743804
# ArrDelay            4682264
# DepDelay            4696662
# Origin              4743804
# Dest                4743804
# Distance            4659638
# TaxiOut                   0
# Cancelled           4743804
# CancellationCode          0
# dtype: int64

# %%
for col in airports.columns:
    print(col, len(airports[col].unique()))
# Out:
# Year 1
# Month 12
# DayofMonth 31
# DayOfWeek 7
# DepTime 1441
# CRSDepTime 1225
# CRSArrTime 1362
# UniqueCarrier 12
# FlightNum 2757
# TailNum 1
# CRSElapsedTime 481
# ArrDelay 722
# DepDelay 735
# Origin 235
# Dest 236
# Distance 1085
# TaxiOut 1
# Cancelled 2
# CancellationCode 1

# %%
airports[airports['Cancelled'] == 1]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  CRSArrTime  \
# 2548738  1990      6           1          5      NaN         900        1007
# 3728181  1990      9          16          7      NaN        1805        1925
# 5178257  1990     12          20          4      NaN        1915        2028
# 3230462  1990      8          13          1      NaN        2125        2241
# 2624432  1990      7          19          4      NaN        1600        1820
# ...       ...    ...         ...        ...      ...         ...         ...
# 1044906  1990      3           6          2      NaN        1430        1743
# 2301386  1990      6          17          7      NaN         800         827
# 4166978  1990     10          27          6      NaN         700         821
# 3195285  1990      8          28          2      NaN        2030        2127
# 3809282  1990      9          14          5      NaN        1910        2057
#
#         UniqueCarrier  FlightNum  TailNum  CRSElapsedTime  ArrDelay  DepDelay  \
# 2548738            AA       1423      NaN              67       NaN       NaN
# 3728181            UA       1510      NaN              80       NaN       NaN
# 5178257            AA        427      NaN              73       NaN       NaN
# 3230462            TW        743      NaN              76       NaN       NaN
# 2624432            US        425      NaN              80       NaN       NaN
# ...               ...        ...      ...             ...       ...       ...
# 1044906            UA        886      NaN             133       NaN       NaN
# 2301386            NW       1475      NaN              87       NaN       NaN
# 4166978            UA       1140      NaN              81       NaN       NaN
# 3195285            NW       1187      NaN             117       NaN       NaN
# 3809282            EA        658      NaN             107       NaN       NaN
#
#         Origin Dest  Distance  TaxiOut  Cancelled  CancellationCode
# 2548738    HOU  DFW     247.0      NaN          1               NaN
# 3728181    IAD  PVD     372.0      NaN          1               NaN
# 5178257    LIT  DFW     304.0      NaN          1               NaN
# 3230462    DEN  SLC     391.0      NaN          1               NaN
# 2624432    ORD  PIT     412.0      NaN          1               NaN
# ...        ...  ...       ...      ...        ...               ...
# 1044906    ONT  DEN     819.0      NaN          1               NaN
# 2301386    AZO  MSP     426.0      NaN          1               NaN
# 4166978    SNA  SFO     372.0      NaN          1               NaN
# 3195285    DTW  MCI     629.0      NaN          1               NaN
# 3809282    GSP  LGA     610.0      NaN          1               NaN
#
# [47142 rows x 19 columns]

# %%
print((airports[airports['Cancelled'] == 1].count()/airports['ArrDelay'].isnull().sum())['Year'], """% of nulls in 
      arrdelay is because of cancellation.""")
# Out:
# 0.766038349041274 % of nulls in
#       arrdelay is because of cancellation.

# %%
# What to do with next instances?
airports[(airports['Cancelled'] == 0) & (airports['ArrDelay'].isnull())]
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  CRSArrTime  \
# 104      1990      1          17          3   1859.0        1430        1554
# 3238280  1990      8          28          2   1830.0        1825        2359
# 713131   1990      2          21          3    700.0         700         830
# 1182146  1990      3           2          5   2215.0        2008          16
# 4991055  1990     12          22          6   1821.0        1645        1823
# ...       ...    ...         ...        ...      ...         ...         ...
# 3563313  1990      9          13          4   1753.0        1755        2023
# 4967446  1990     12          29          6   2033.0        1940        2245
# 2352092  1990      6          14          4    725.0         726        1313
# 814743   1990      2          10          6    915.0         915        1030
# 394596   1990      1          23          2   1640.0        1605        1655
#
#         UniqueCarrier  FlightNum  TailNum  CRSElapsedTime  ArrDelay  DepDelay  \
# 104                US         29      NaN              84       NaN     269.0
# 3238280            UA        166      NaN             214       NaN       5.0
# 713131             EA        853      NaN              90       NaN       0.0
# 1182146            AA        240      NaN             188       NaN     127.0
# 4991055            TW        369      NaN             158       NaN      96.0
# ...               ...        ...      ...             ...       ...       ...
# 3563313            US       1209      NaN             148       NaN      -2.0
# 4967446            NW       1154      NaN             125       NaN      53.0
# 2352092            UA        504      NaN             227       NaN      -1.0
# 814743             CO        550      NaN              75       NaN       0.0
# 394596             AS         67      NaN              50       NaN      35.0
#
#         Origin Dest  Distance  TaxiOut  Cancelled  CancellationCode
# 104        PHL  CMH     405.0      NaN          0               NaN
# 3238280    DEN  LGA    1619.0      NaN          0               NaN
# 713131     BOS  ATL     946.0      NaN          0               NaN
# 1182146    DFW  LGA    1389.0      NaN          0               NaN
# 4991055    RSW  STL     979.0      NaN          0               NaN
# ...        ...  ...       ...      ...        ...               ...
# 3563313    MIA  BWI     946.0      NaN          0               NaN
# 4967446    MEM  PHL     874.0      NaN          0               NaN
# 2352092    ONT  ORD    1700.0      NaN          0               NaN
# 814743     EWR  PWM     284.0      NaN          0               NaN
# 394596     KTN  SIT       NaN      NaN          0               NaN
#
# [14398 rows x 19 columns]

# %%
# Flightnums are used by different carriers to identify their trips. 
airports_full[airports_full['FlightNum'] == 1423].sort_values(by='Month', inplace=False)
# Out:
#          Year  Month  DayofMonth  DayOfWeek  DepTime  CRSDepTime  CRSArrTime  \
# 48977    1990      1           1          1   2034.0        1945        2045
# 215709   1990      1           4          4   1800.0        1800        1913
# 215708   1990      1           3          3   1757.0        1800        1913
# 215707   1990      1           2          2   1800.0        1800        1913
# 215706   1990      1           1          1   1814.0        1800        1913
# ...       ...    ...         ...        ...      ...         ...         ...
# 4971086  1990     12          11          2   1847.0        1850        1949
# 4971087  1990     12          12          3   1851.0        1850        1949
# 4971088  1990     12          13          4   1847.0        1850        1949
# 4971078  1990     12           3          1   1848.0        1850        1949
# 5214756  1990     12          31          1    902.0         900        1012
#
#         UniqueCarrier  FlightNum  TailNum  CRSElapsedTime  ArrDelay  DepDelay  \
# 48977              US       1423      NaN              60      40.0      49.0
# 215709             UA       1423      NaN              73      -1.0       0.0
# 215708             UA       1423      NaN              73      -4.0      -3.0
# 215707             UA       1423      NaN              73      -4.0       0.0
# 215706             UA       1423      NaN              73      24.0      14.0
# ...               ...        ...      ...             ...       ...       ...
# 4971086            NW       1423      NaN              59       4.0      -3.0
# 4971087            NW       1423      NaN              59       3.0       1.0
# 4971088            NW       1423      NaN              59       4.0      -3.0
# 4971078            NW       1423      NaN              59       7.0      -2.0
# 5214756            AA       1423      NaN              72      -6.0       2.0
#
#         Origin Dest  Distance  TaxiOut  Cancelled  CancellationCode
# 48977      BWI  ROA     221.0      NaN          0               NaN
# 215709     SFO  LAX     337.0      NaN          0               NaN
# 215708     SFO  LAX     337.0      NaN          0               NaN
# 215707     SFO  LAX     337.0      NaN          0               NaN
# 215706     SFO  LAX     337.0      NaN          0               NaN
# ...        ...  ...       ...      ...        ...               ...
# 4971086    BNA  MEM     200.0      NaN          0               NaN
# 4971087    BNA  MEM     200.0      NaN          0               NaN
# 4971088    BNA  MEM     200.0      NaN          0               NaN
# 4971078    BNA  MEM     200.0      NaN          0               NaN
# 5214756    HOU  DFW     247.0      NaN          0               NaN
#
# [1867 rows x 19 columns]

# %% [markdown]
# ## Select factors based on correlations

# %%
corr_matrix = airports.corr()

# %%
corr_matrix['ArrDelay'].sort_values()
# Out:
# FlightNum          -0.025337
# Month              -0.015513
# DayOfWeek           0.017746
# CRSElapsedTime      0.019811
# Distance            0.023804
# DayofMonth          0.023977
# CRSDepTime          0.088501
# CRSArrTime          0.091844
# DepTime             0.117615
# DepDelay            0.833443
# ArrDelay            1.000000
# Year                     NaN
# TailNum                  NaN
# TaxiOut                  NaN
# Cancelled                NaN
# CancellationCode         NaN
# Name: ArrDelay, dtype: float64

# %%
# Check the scatterplot
sns.scatterplot(data=airports, x= 'DepDelay', y = 'ArrDelay')
plt.show()

# %%
sns.scatterplot(data=airports, x= 'Distance', y = 'ArrDelay')
plt.show()

# %%
airports['ResDelay'] = airports['ArrDelay'] - airports['DepDelay']
sns.scatterplot(data=airports, x= 'Distance', y = 'ResDelay')
plt.show()

# %% [markdown]
# ## Variables based on categories
# For example day of week can be seen as category. Weekends can be more busy. As is shown in data as well by second plot with mean of delay per day.
# The errors in the plots are the standard error of the mean, defined as:
# $$ \sigma_{\bar{x}} = \frac{\sigma}{\sqrt{n}}$$
# In each of the categories there seems to be a difference.
# I have created a new variable called "ResDelay", this is a residual delay after subtracting the departure delay from the arrival delay. It could for example be that one company always departs before planned time and therefore has low arrival delays. Plots are made for different variables.

# %%
def plot_with_error_bars(x, y, data=airports):
    """Function that plots data with the mean of y grouped by the values of x"""
    
    grouped_month = data.groupby(x).agg([np.mean, np.std, 'count'])[y]
    # Standard error of mean is defined as std / sqrt(n) 
    grouped_month['error'] = grouped_month['std'] / np.sqrt(grouped_month['count'])
    
    if type(x) == str: 
        title = y + " by " + x
    else:
        title = y + " by " + " and ".join(x)
    grouped_month.plot(kind = "bar", y = "mean", legend = False,  
              yerr = "error", title = title)
    plt.show()

# %%
sns.boxplot(data=airports, x= 'DayOfWeek', y = 'ArrDelay')
plt.show()
plot_with_error_bars(x='DayOfWeek', y='ArrDelay')
plot_with_error_bars(x='DayOfWeek', y='ResDelay')

# %%
plot_with_error_bars(x='Month', y='ArrDelay')
plot_with_error_bars(x='Month', y='ResDelay')

# %%
plot_with_error_bars(x='UniqueCarrier', y='ArrDelay')
plot_with_error_bars(x='UniqueCarrier', y='ResDelay')

# %%
plot_with_error_bars(x='DayofMonth', y="ArrDelay")
plot_with_error_bars(x='DayofMonth', y="ResDelay")

# %%
airports['DepHour'] = airports["CRSDepTime"]//100

plot_with_error_bars(x='DepHour', y="ArrDelay")
plot_with_error_bars(x='DepHour', y="ResDelay")

# %%
airports['ArrHour'] = airports["CRSArrTime"]//100

plot_with_error_bars(x='ArrHour', y="ArrDelay")
plot_with_error_bars(x='ArrHour', y="ResDelay")

# %% [markdown]
# Below are some plots that are not very clear, but there seem to be some difference between origin and destinations.

# %%
plot_with_error_bars(x='Origin', y="ArrDelay")
plot_with_error_bars(x='Origin', y="ResDelay")

# %%
plot_with_error_bars(x='Dest', y="ArrDelay")
plot_with_error_bars(x='Dest', y="ResDelay")

# %%
plot_with_error_bars(x=['UniqueCarrier', 'DayOfWeek'] , y='ArrDelay')
plot_with_error_bars(x=['UniqueCarrier', 'DayOfWeek'], y='ResDelay')
